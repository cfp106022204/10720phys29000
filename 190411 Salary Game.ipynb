# %%
# People have no money can't play any game.
import numpy as np
import matplotlib.pyplot as plt
n,m,k,dm=500,40,10000,10
money=[m for i in range(0,n)]

for i in range(k):
    p1=p2=0
    while (p1==p2 or money[p1]==0 or money[p2]==0):
        p1=np.random.randint(0,n)
        p2=np.random.randint(0,n)
    
    win=np.random.randint(0,2)
    if (win==0 ):
        money[p1]-=dm
        money[p2]+=dm
    elif (win==1 ):
        money[p1]+=dm
        money[p2]-=dm

bins=10
plt.clf()
plt.hist(money,bins)
plt.xlabel("Money")
plt.ylabel("Number of Student")
plt.title("Salary Game")
plt.ylim(0,n)
plt.show()

# %%
# People with no money can win money again.
import numpy as np
import matplotlib.pyplot as plt
n,m,k,dm=500,40,10000,10
money=[m for i in range(0,n)]

for i in range(k):
    p1=p2=0
    while (p1==p2):
        p1=np.random.randint(0,n)
        p2=np.random.randint(0,n)
    
    win=np.random.randint(0,2)
    if (win==0 and money[p1]!=0):
        money[p1]-=dm
        money[p2]+=dm
    elif (win==1 and money[p2]!=0):
        money[p1]+=dm
        money[p2]-=dm

bins=10
plt.clf()
plt.hist(money,bins)
plt.xlabel("Money")
plt.ylabel("Number of Student")
plt.title("Salary Game")
plt.ylim(0,n)
plt.show()

# %%
# Every one can play game no matter they have money or not.
import numpy as np
import matplotlib.pyplot as plt
n,m,k,dm=500,40,10000,10
money=[m for i in range(0,n)]

for i in range(k):
    p1=p2=0
    while (p1==p2):
        p1=np.random.randint(0,n)
        p2=np.random.randint(0,n)
    
    win=np.random.randint(0,2)
    if (win==0):
        money[p1]-=dm
        money[p2]+=dm
    else:
        money[p1]+=dm
        money[p2]-=dm

bins=10
plt.clf()
plt.hist(money,bins)
plt.xlabel("Money")
plt.ylabel("Number of Student")
plt.title("Salary Game")
plt.ylim(0,n)
plt.show()

# %%
# People have no money can't play any game.
import numpy as np
import matplotlib.pyplot as plt
n,m,k,dm=500,40,10000,10
money=[m for i in range(0,n)]

for i in range(k):
    p1=p2=0
    while (p1==p2 or money[p1]==0 or money[p2]==0):
        p1=np.random.randint(0,n)
        p2=np.random.randint(0,n)
    
    win=np.random.randint(0,2)
    if (win==0 ):
        money[p1]-=dm
        money[p2]+=dm
    elif (win==1 ):
        money[p1]+=dm
        money[p2]-=dm

bins=10
plt.clf()
a=plt.hist(money,bins)
print(a)

dx=a[1][1]-a[1][0]
bin_center=np.array(a[1][0:-1])+dx/2.
print(bin_center)

from scipy import optimize

def test_func(x, amp):
    return amp*np.exp(-x/50)

params, params_covariance = optimize.curve_fit(test_func, bin_center, a[0])
print(params, params_covariance)
plt.plot(bin_center, test_func(bin_center, params[0]),"r*",label='Fitted funtion')

plt.xlabel("Money")
plt.ylabel("Number of Students")
plt.show()
# Out:
# (array([328.,  15.,  31.,  24.,  31.,  20.,  23.,   9.,  16.,   3.]), array([  0.,  25.,  50.,  75., 100., 125., 150., 175., 200., 225., 250.]), <a list of 10 Patch objects>)
# [ 12.5  37.5  62.5  87.5 112.5 137.5 162.5 187.5 212.5 237.5]
# [293.37742836] [[3358.29735694]]
